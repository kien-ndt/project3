# %%
from google.colab import drive
drive.mount('/content/driver', force_remount=True)
# Out:
# Mounted at /content/driver

# %%
# path = '/content/driver/My Drive/Colab Notebooks/finaltest/SVR/datacsv/k62/'
path = '/content/driver/My Drive/Colab Notebooks/alldatacsv/'
#file du lieu train test tot nhat moi dong 1 file
pathTrainTest = '/content/driver/My Drive/project3model/'


fileTest= pathTrainTest+'fileTest.txt'
fileTrain= pathTrainTest+'fileTrain.txt'
modelDir = '/content/driver/My Drive/project3model/ACXT.joblib.dat'

resFile = '/content/driver/My Drive/project3model/resultAC.csv'

# %%
from glob import glob
import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np
 
files = glob(path)

def mean(_true, _pred):
  return max(1-abs(_true-_pred)/_true, 0)

# %%
from sklearn.metrics import explained_variance_score
def mean_absolute_percentage_error(y_true, y_pred, start_of_test):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    # return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print("Gia tri thuc: ", np.average(y_true))
    print("Gia tri du doan: ", np.average(y_pred))
    return np.average(y_true),np.average(y_pred)

def mean_absolute_percentage_error_25(y_true, y_pred, start_of_test):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
 
    y_true_25 = np.array([])
    y_pred_25 = np.array([])
    for element in range(count_test):
        t = start_of_test[element] + math.floor(len_of_test[element] / 4)
        y_true_25 = np.concatenate((y_true_25, np.array([ y_true[ int(t.item()) ] ])))
        y_pred_25 = np.concatenate((y_pred_25, np.array([ y_pred[ int(t.item()) ] ])))
    # return np.mean(np.abs((y_true_25 - y_pred_25) / y_true_25)) * 100
    print("Gia tri thuc: ", np.average(y_true))
    print("Gia tri du doan: ", np.average(y_pred_25))
    return np.average(y_true),np.average(y_pred_25)

def mean_absolute_percentage_error_1_to_25(y_true, y_pred, start_of_test):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
 
    y_true_1_to_25 = np.array([])
    y_pred_1_to_25 = np.array([])
    for element in range(count_test):
        t = start_of_test[element] + math.floor(len_of_test[element] / 4)
        for t_value in range( int(start_of_test[element].item()), int(t.item()) ):
            y_true_1_to_25 = np.concatenate((y_true_1_to_25, np.array([ y_true[ t_value ] ])))
            y_pred_1_to_25 = np.concatenate((y_pred_1_to_25, np.array([ y_pred[ t_value ] ])))
    # return np.mean(np.abs((y_true_1_to_25 - y_pred_1_to_25) / y_true_1_to_25)) * 100
    print("Gia tri thuc: ", np.average(y_true))
    print("Gia tri du doan: ", np.average(y_pred_1_to_25))
    return np.average(y_true),np.average(y_pred_1_to_25)
 
def mean_absolute_percentage_error_50(y_true, y_pred, start_of_test):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
 
    y_true_50 = np.array([])
    y_pred_50 = np.array([])
    for element in range(count_test):
        t = start_of_test[element] + math.floor(len_of_test[element] / 2)
        y_true_50 = np.concatenate((y_true_50, np.array([ y_true[ int(t.item()) ] ])))
        y_pred_50 = np.concatenate((y_pred_50, np.array([ y_pred[ int(t.item()) ] ])))
    # return np.mean(np.abs((y_true_50 - y_pred_50) / y_true_50)) * 100
    print("Gia tri thuc: ", np.average(y_true))
    print("Gia tri du doan: ", np.average(y_pred_50))
    return np.average(y_true),np.average(y_pred_50)

def mean_absolute_percentage_error_1_to_50(y_true, y_pred, start_of_test):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
 
    y_true_1_to_50 = np.array([])
    y_pred_1_to_50 = np.array([])
    for element in range(count_test):
        t = start_of_test[element] + math.floor(len_of_test[element] / 2)
        for t_value in range( int(start_of_test[element].item()), int(t.item()) ):
            y_true_1_to_50 = np.concatenate((y_true_1_to_50, np.array([ y_true[ t_value ] ])))
            y_pred_1_to_50 = np.concatenate((y_pred_1_to_50, np.array([ y_pred[ t_value ] ])))
    # return np.mean(np.abs((y_true_1_to_50 - y_pred_1_to_50) / y_true_1_to_50)) * 100
    print("Gia tri thuc: ", np.average(y_true))
    print("Gia tri du doan: ", np.average(y_pred_1_to_50))
    return np.average(y_true), np.average(y_pred_1_to_50)

# %%
filetest = open(fileTest,'r')

li2 = []
for line in filetest: 
    df = pd.read_csv(line.strip(), index_col = None, header = 0)
    li2.append(df)  
dataFrame2 = pd.concat(li2, axis = 0, ignore_index = True)
X_test, y_test = dataFrame2.iloc[:, [2, 3]], dataFrame2.iloc[:, 7] 
print(X_test)
print(y_test)
# Out:
#            XT             AC
# 0    0.154979    9077.039917
# 1    0.394426   21474.189819
# 2    0.661368   38574.709595
# 3    1.000000   57822.399780
# 4    0.061884  531720.000000
# ..        ...            ...
# 378  1.000000   56748.329407
# 379  0.182045   90202.000000
# 380  0.429667  213819.000000
# 381  0.512281  255720.000000
# 382  1.000000  496991.000000
#
# [383 rows x 2 columns]
# 0      5.782240e+04
# 1      5.782240e+04
# 2      5.782240e+04
# 3      5.782240e+04
# 4      5.414544e+06
#            ...
# 378    5.674833e+04
# 379    4.969910e+05
# 380    4.969910e+05
# 381    4.969910e+05
# 382    4.969910e+05
# Name: TOTAL_AC, Length: 383, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.model_selection import GridSearchCV
from joblib import dump
from sklearn.svm import SVR 
from joblib import load
import math
loaded_model = load(modelDir)
filetest = open(fileTest,'r')
import csv
resCsv = open(resFile, mode='w')
resCsv = csv.writer(resCsv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
resCsv.writerow(['Mã', 'Loai', 'Thuc te', 'Du doan', 'Chinh xac'])
for line in filetest: 
  li2=[]
  df = pd.read_csv(line.strip(), index_col = None, header = 0)
  li2.append(df)  
  dataFrame2 = pd.concat(li2, axis = 0, ignore_index = True)
  X_test, y_test = dataFrame2.iloc[:, [2, 3]], dataFrame2.iloc[:, 7] 
  preds = loaded_model.predict(X_test)

  dir = line.replace(path,"")
  dir = dir.replace("\n","")
  print(dir) 
  preds = loaded_model.predict(X_test)

  # Thông tin test
  y_test_ward = np.concatenate((y_test, np.array([0])))
  count_test = 0
  len_of_test = np.array([])
  tmp = 1
  for element in range(len(y_test_ward) - 1):
      if y_test_ward[element] != y_test_ward[element + 1]:
          count_test = count_test + 1
          len_of_test = np.concatenate((len_of_test, np.array([tmp])))
          tmp = 1
      else:
          tmp = tmp + 1
  start_of_test = np.array([0])
  for element in range(1, count_test):
      start_of_test = np.concatenate((start_of_test, np.array([ len_of_test[element - 1] + start_of_test[element - 1] ])))
    
  print("Độ chính xác dự đoán thời gian của dữ liệu K62:")
  print('Tất cả thời điểm:')
  resTest, resPred = mean_absolute_percentage_error(y_test, preds, start_of_test)
  print(mean(resTest,resPred)*100)
  resCsv.writerow([dir, 'tat ca', resTest, resPred, mean(resTest,resPred)*100]) 

  print('25%:')
  resTest, resPred = mean_absolute_percentage_error_25(y_test, preds, start_of_test)
  print(mean(resTest,resPred)*100)
  resCsv.writerow([dir, '25', resTest, resPred, mean(resTest,resPred)*100]) 
  print(dir, '25', resTest, resPred, mean(resTest,resPred)*100)
  print('1 -> 25%:')
  resTest, resPred = mean_absolute_percentage_error_1_to_25(y_test, preds, start_of_test)
  print(mean(resTest,resPred)*100)
  resCsv.writerow([dir, '1 -> 25', resTest, resPred, mean(resTest,resPred)*100]) 
  
  print('50%:')
  resTest, resPred = mean_absolute_percentage_error_50(y_test, preds, start_of_test)
  print(mean(resTest,resPred)*100)
  resCsv.writerow([dir, '50', resTest, resPred, mean(resTest,resPred)*100]) 
  
  print('1 -> 50%:')
  resTest, resPred = mean_absolute_percentage_error_1_to_50(y_test, preds, start_of_test)
  print(mean(resTest,resPred)*100)
  resCsv.writerow([dir, '1 -> 50', resTest, resPred, mean(resTest,resPred)*100]) 
  
  
  resCsv.writerow(['-----', '------', '------', '------', '------']) 
  print('------------------------------------------------------')
  # rmse = np.sqrt(mean_squared_error(y_test, preds))
# Out:
# C2016-22.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  57822.399780273496
# Gia tri du doan:  162869.70297484472
# 0
# 25%:
# Gia tri thuc:  57822.399780273496
# Gia tri du doan:  151242.64394060895
# 0
# C2016-22.csv 25 57822.399780273496 151242.64394060895 0
# 1 -> 25%:
# Gia tri thuc:  57822.399780273496
# Gia tri du doan:  141232.5768621154
# 0
# 50%:
# Gia tri thuc:  57822.399780273496
# Gia tri du doan:  168111.81469251588
# 0
# 1 -> 50%:
# Gia tri thuc:  57822.399780273496
# Gia tri du doan:  146237.61040136218
# 0
# ------------------------------------------------------
# C2015-07.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  5414544.0
# Gia tri du doan:  12608310.849569125
# 0
# 25%:
# Gia tri thuc:  5414544.0
# Gia tri du doan:  2681401.8566079214
# 49.522210117932765
# C2015-07.csv 25 5414544.0 2681401.8566079214 49.522210117932765
# 1 -> 25%:
# Gia tri thuc:  5414544.0
# Gia tri du doan:  1136493.3455238715
# 20.98964096558956
# 50%:
# Gia tri thuc:  5414544.0
# Gia tri du doan:  10890787.296153605
# 0
# 1 -> 50%:
# Gia tri thuc:  5414544.0
# Gia tri du doan:  3736473.1369960587
# 69.00808520525568
# ------------------------------------------------------
# C2014-01.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  39777643.3007812
# Gia tri du doan:  30427553.426701188
# 76.49410800087199
# 25%:
# Gia tri thuc:  39777643.3007812
# Gia tri du doan:  26087596.232539892
# 65.58356420282836
# C2014-01.csv 25 39777643.3007812 26087596.232539892 65.58356420282836
# 1 -> 25%:
# Gia tri thuc:  39777643.3007812
# Gia tri du doan:  17818401.184623033
# 44.79501475210095
# 50%:
# Gia tri thuc:  39777643.3007812
# Gia tri du doan:  36009869.306076296
# 90.52791044905642
# 1 -> 50%:
# Gia tri thuc:  39777643.3007812
# Gia tri du doan:  22547344.214381848
# 56.683459208200595
# ------------------------------------------------------
# C2016-28.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  586086.849975586
# Gia tri du doan:  761795.525271602
# 70.02002769669116
# 25%:
# Gia tri thuc:  586086.849975586
# Gia tri du doan:  860989.8844388276
# 53.09517105277266
# C2016-28.csv 25 586086.849975586 860989.8844388276 53.09517105277266
# 1 -> 25%:
# Gia tri thuc:  586086.849975586
# Gia tri du doan:  379590.6447287947
# 64.76696154240739
# 50%:
# Gia tri thuc:  586086.849975586
# Gia tri du doan:  873384.1027769372
# 50.980430150698865
# 1 -> 50%:
# Gia tri thuc:  586086.849975586
# Gia tri du doan:  620290.2645838112
# 94.16410475518263
# ------------------------------------------------------
# C2016-04.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  906253.8671875
# Gia tri du doan:  818736.3437292101
# 90.34293517224981
# 25%:
# Gia tri thuc:  906253.8671875
# Gia tri du doan:  825998.5418175347
# 91.14427774868068
# C2016-04.csv 25 906253.8671875 825998.5418175347 91.14427774868068
# 1 -> 25%:
# Gia tri thuc:  906253.8671875
# Gia tri du doan:  339843.21042030305
# 37.49978043955656
# 50%:
# Gia tri thuc:  906253.8671875
# Gia tri du doan:  927683.2466588914
# 97.63538890731621
# 1 -> 50%:
# Gia tri thuc:  906253.8671875
# Gia tri du doan:  598916.1443493105
# 66.08701667756827
# ------------------------------------------------------
# C2011-07.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  191065.05999634002
# Gia tri du doan:  240037.97826191556
# 74.3684594836368
# 25%:
# Gia tri thuc:  191065.05999634002
# Gia tri du doan:  148743.2436199449
# 77.84952603201977
# C2011-07.csv 25 191065.05999634002 148743.2436199449 77.84952603201977
# 1 -> 25%:
# Gia tri thuc:  191065.05999634002
# Gia tri du doan:  142037.5907750681
# 74.3399084991201
# 50%:
# Gia tri thuc:  191065.05999634002
# Gia tri du doan:  158397.1189331822
# 82.90218993269434
# 1 -> 50%:
# Gia tri thuc:  191065.05999634002
# Gia tri du doan:  148046.21348562464
# 77.48471305452738
# ------------------------------------------------------
# C2013-13.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  955929.2242979999
# Gia tri du doan:  1014189.5162564425
# 93.90537599671912
# 25%:
# Gia tri thuc:  955929.2242979999
# Gia tri du doan:  971770.7904377952
# 98.34280972512073
# C2013-13.csv 25 955929.2242979999 971770.7904377952 98.34280972512073
# 1 -> 25%:
# Gia tri thuc:  955929.2242979999
# Gia tri du doan:  575257.7337531988
# 60.177858269334465
# 50%:
# Gia tri thuc:  955929.2242979999
# Gia tri du doan:  1188966.8058352023
# 75.62187915027529
# 1 -> 50%:
# Gia tri thuc:  955929.2242979999
# Gia tri du doan:  784081.6280786125
# 82.02297912321008
# ------------------------------------------------------
# C2016-03.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  910728.0108642579
# Gia tri du doan:  954911.3978896883
# 95.14856395121728
# 25%:
# Gia tri thuc:  910728.0108642579
# Gia tri du doan:  885450.8686567321
# 97.22451248825229
# C2016-03.csv 25 910728.0108642579 885450.8686567321 97.22451248825229
# 1 -> 25%:
# Gia tri thuc:  910728.0108642579
# Gia tri du doan:  598833.2797968537
# 65.75325153649068
# 50%:
# Gia tri thuc:  910728.0108642579
# Gia tri du doan:  983744.0818362422
# 91.98266989694389
# 1 -> 50%:
# Gia tri thuc:  910728.0108642579
# Gia tri du doan:  795490.6333485655
# 87.3466747326312
# ------------------------------------------------------
# data_020.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  2512524.0
# Gia tri du doan:  2054244.259740337
# 81.76018456899664
# 25%:
# Gia tri thuc:  2512524.0
# Gia tri du doan:  1045078.7784930393
# 41.59477794015258
# data_020.csv 25 2512524.0 1045078.7784930393 41.59477794015258
# 1 -> 25%:
# Gia tri thuc:  2512524.0
# Gia tri du doan:  947564.602790609
# 37.713653791590005
# 50%:
# Gia tri thuc:  2512524.0
# Gia tri du doan:  2707610.270328723
# 92.23544649409428
# 1 -> 50%:
# Gia tri thuc:  2512524.0
# Gia tri du doan:  1285312.4110629298
# 51.15622422165637
# ------------------------------------------------------
# data_012.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  494947.71249999997
# Gia tri du doan:  536858.7289189512
# 91.53223353488046
# 25%:
# Gia tri thuc:  494947.71249999997
# Gia tri du doan:  361168.06451184675
# 72.97095337355393
# data_012.csv 25 494947.71249999997 361168.06451184675 72.97095337355393
# 1 -> 25%:
# Gia tri thuc:  494947.71249999997
# Gia tri du doan:  246135.910550271
# 49.72967938512717
# 50%:
# Gia tri thuc:  494947.71249999997
# Gia tri du doan:  505722.65008586645
# 97.82301497436126
# 1 -> 50%:
# Gia tri thuc:  494947.71249999997
# Gia tri du doan:  316824.0313241508
# 64.01161644406041
# ------------------------------------------------------
# C2015-20.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  11100.0
# Gia tri du doan:  142277.61494492088
# 0
# 25%:
# Gia tri thuc:  11100.0
# Gia tri du doan:  142068.75671765953
# 0
# C2015-20.csv 25 11100.0 142068.75671765953 0
# 1 -> 25%:
# Gia tri thuc:  11100.0
# Gia tri du doan:  141647.77491175383
# 0
# 50%:
# Gia tri thuc:  11100.0
# Gia tri du doan:  142663.06261385605
# 0
# 1 -> 50%:
# Gia tri thuc:  11100.0
# Gia tri du doan:  141858.26581470668
# 0
# ------------------------------------------------------
# data_017.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  1314584.5820000002
# Gia tri du doan:  958194.5107280364
# 72.88952904576485
# 25%:
# Gia tri thuc:  1314584.5820000002
# Gia tri du doan:  488240.25048165396
# 37.14026903760339
# data_017.csv 25 1314584.5820000002 488240.25048165396 37.14026903760339
# 1 -> 25%:
# Gia tri thuc:  1314584.5820000002
# Gia tri du doan:  161154.49534170702
# 12.258967399155685
# 50%:
# Gia tri thuc:  1314584.5820000002
# Gia tri du doan:  1021404.8924007267
# 77.69792118258135
# 1 -> 50%:
# Gia tri thuc:  1314584.5820000002
# Gia tri du doan:  514705.0819488391
# 39.15343972510086
# ------------------------------------------------------
# C2014-02.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  190266.49902343808
# Gia tri du doan:  270118.82788331
# 58.03132486816018
# 25%:
# Gia tri thuc:  190266.49902343808
# Gia tri du doan:  211317.6101711467
# 88.93598649486087
# C2014-02.csv 25 190266.49902343808 211317.6101711467 88.93598649486087
# 1 -> 25%:
# Gia tri thuc:  190266.49902343808
# Gia tri du doan:  192375.52541917298
# 98.89154086160218
# 50%:
# Gia tri thuc:  190266.49902343808
# Gia tri du doan:  241239.4912210144
# 73.20968617218463
# 1 -> 50%:
# Gia tri thuc:  190266.49902343808
# Gia tri du doan:  209337.59783632334
# 89.97663860386899
# ------------------------------------------------------
# C2016-20.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  53783.280151367195
# Gia tri du doan:  160939.17327091936
# 0
# 25%:
# Gia tri thuc:  53783.280151367195
# Gia tri du doan:  151597.57266771793
# 0
# C2016-20.csv 25 53783.280151367195 151597.57266771793 0
# 1 -> 25%:
# Gia tri thuc:  53783.280151367195
# Gia tri du doan:  141052.5051434189
# 0
# 50%:
# Gia tri thuc:  53783.280151367195
# Gia tri du doan:  165302.2339254059
# 0
# 1 -> 50%:
# Gia tri thuc:  53783.280151367195
# Gia tri du doan:  146325.03890556842
# 0
# ------------------------------------------------------
# C2016-18.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  60829.51953125
# Gia tri du doan:  166034.60473634303
# 0
# 25%:
# Gia tri thuc:  60829.51953125
# Gia tri du doan:  155365.20518013835
# 0
# C2016-18.csv 25 60829.51953125 155365.20518013835 0
# 1 -> 25%:
# Gia tri thuc:  60829.51953125
# Gia tri du doan:  142314.08653350174
# 0
# 50%:
# Gia tri thuc:  60829.51953125
# Gia tri du doan:  171679.9677572213
# 0
# 1 -> 50%:
# Gia tri thuc:  60829.51953125
# Gia tri du doan:  148839.64585682005
# 0
# ------------------------------------------------------
# Sheet21.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  224789.6707
# Gia tri du doan:  335187.2145249583
# 50.888515703956536
# 25%:
# Gia tri thuc:  224789.6707
# Gia tri du doan:  261496.8850797303
# 83.6704176551248
# Sheet21.csv 25 224789.6707 261496.8850797303 83.6704176551248
# 1 -> 25%:
# Gia tri thuc:  224789.6707
# Gia tri du doan:  158565.45010712743
# 70.539473461281
# 50%:
# Gia tri thuc:  224789.6707
# Gia tri du doan:  351295.11148975044
# 43.722751852516296
# 1 -> 50%:
# Gia tri thuc:  224789.6707
# Gia tri du doan:  210031.16759342887
# 93.4345279030781
# ------------------------------------------------------
# C2013-09.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  1696971.78688812
# Gia tri du doan:  1557432.4767654135
# 91.77715792325625
# 25%:
# Gia tri thuc:  1696971.78688812
# Gia tri du doan:  826293.0045624711
# 48.692206372960044
# C2013-09.csv 25 1696971.78688812 826293.0045624711 48.692206372960044
# 1 -> 25%:
# Gia tri thuc:  1696971.78688812
# Gia tri du doan:  605169.041682316
# 35.661703179642444
# 50%:
# Gia tri thuc:  1696971.78688812
# Gia tri du doan:  1587723.332510069
# 93.56215258131138
# 1 -> 50%:
# Gia tri thuc:  1696971.78688812
# Gia tri du doan:  891964.9598662041
# 52.56215611585831
# ------------------------------------------------------
# Sheet19.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  440940.89049999986
# Gia tri du doan:  475070.44567721925
# 92.25983438766167
# 25%:
# Gia tri thuc:  440940.89049999986
# Gia tri du doan:  342546.94868637994
# 77.68545763536531
# Sheet19.csv 25 440940.89049999986 342546.94868637994 77.68545763536531
# 1 -> 25%:
# Gia tri thuc:  440940.89049999986
# Gia tri du doan:  224381.19241281226
# 50.886909616927966
# 50%:
# Gia tri thuc:  440940.89049999986
# Gia tri du doan:  460332.07457073405
# 95.60231666227511
# 1 -> 50%:
# Gia tri thuc:  440940.89049999986
# Gia tri du doan:  320477.7834117604
# 72.6804409199515
# ------------------------------------------------------
# C2013-10.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  15218926.378898604
# Gia tri du doan:  12532309.674530774
# 82.34687101126342
# 25%:
# Gia tri thuc:  15218926.378898604
# Gia tri du doan:  2170334.739909012
# 14.26076114618855
# C2013-10.csv 25 15218926.378898604 2170334.739909012 14.26076114618855
# 1 -> 25%:
# Gia tri thuc:  15218926.378898604
# Gia tri du doan:  1233404.0713834353
# 8.104409211766594
# 50%:
# Gia tri thuc:  15218926.378898604
# Gia tri du doan:  9801686.747016128
# 64.40458743927164
# 1 -> 50%:
# Gia tri thuc:  15218926.378898604
# Gia tri du doan:  2371320.510803441
# 15.581391563148184
# ------------------------------------------------------
# C2013-08.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  576624.051826477
# Gia tri du doan:  637166.0835357469
# 89.50060589434298
# 25%:
# Gia tri thuc:  576624.051826477
# Gia tri du doan:  430636.97396234795
# 74.68245082706663
# C2013-08.csv 25 576624.051826477 430636.97396234795 74.68245082706663
# 1 -> 25%:
# Gia tri thuc:  576624.051826477
# Gia tri du doan:  234025.94469056278
# 40.58553297408898
# 50%:
# Gia tri thuc:  576624.051826477
# Gia tri du doan:  710698.345445741
# 76.74840423416629
# 1 -> 50%:
# Gia tri thuc:  576624.051826477
# Gia tri du doan:  413329.7093522095
# 71.68096926289722
# ------------------------------------------------------
# C2015-06.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  186107.000299454
# Gia tri du doan:  307642.67588473746
# 34.695806503931905
# 25%:
# Gia tri thuc:  186107.000299454
# Gia tri du doan:  228363.8790279925
# 77.2943099074482
# C2015-06.csv 25 186107.000299454 228363.8790279925 77.2943099074482
# 1 -> 25%:
# Gia tri thuc:  186107.000299454
# Gia tri du doan:  160661.84042870626
# 86.32767180718328
# 50%:
# Gia tri thuc:  186107.000299454
# Gia tri du doan:  348497.76912136003
# 12.74333122310689
# 1 -> 50%:
# Gia tri thuc:  186107.000299454
# Gia tri du doan:  226791.01787278353
# 78.13944800148988
# ------------------------------------------------------
# C2015-02.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  967988.7905375508
# Gia tri du doan:  820800.4113484765
# 84.79441284569664
# 25%:
# Gia tri thuc:  967988.7905375508
# Gia tri du doan:  646268.1793631092
# 66.7640147985824
# C2015-02.csv 25 967988.7905375508 646268.1793631092 66.7640147985824
# 1 -> 25%:
# Gia tri thuc:  967988.7905375508
# Gia tri du doan:  467164.8183950484
# 48.2613872145791
# 50%:
# Gia tri thuc:  967988.7905375508
# Gia tri du doan:  857072.1639220268
# 88.54153811492704
# 1 -> 50%:
# Gia tri thuc:  967988.7905375508
# Gia tri du doan:  583532.5491947802
# 60.282986218335076
# ------------------------------------------------------
# C2016-10.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  14466100.0
# Gia tri du doan:  24656366.81263447
# 29.55760839041295
# 25%:
# Gia tri thuc:  14466100.0
# Gia tri du doan:  21483945.43898185
# 51.48764740336477
# C2016-10.csv 25 14466100.0 21483945.43898185 51.48764740336477
# 1 -> 25%:
# Gia tri thuc:  14466100.0
# Gia tri du doan:  25359401.670848016
# 24.697730066514023
# 50%:
# Gia tri thuc:  14466100.0
# Gia tri du doan:  25737428.950287078
# 22.08453591301679
# 1 -> 50%:
# Gia tri thuc:  14466100.0
# Gia tri du doan:  24364173.959180318
# 31.577453776896903
# ------------------------------------------------------
# C2016-27.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  879701.060546875
# Gia tri du doan:  704371.9861205434
# 80.06947106357512
# 25%:
# Gia tri thuc:  879701.060546875
# Gia tri du doan:  586788.9319003746
# 66.70321978873042
# C2016-27.csv 25 879701.060546875 586788.9319003746 66.70321978873042
# 1 -> 25%:
# Gia tri thuc:  879701.060546875
# Gia tri du doan:  148977.50218691304
# 16.935014503028977
# 50%:
# Gia tri thuc:  879701.060546875
# Gia tri du doan:  966778.9748105034
# 90.10141988353458
# 1 -> 50%:
# Gia tri thuc:  879701.060546875
# Gia tri du doan:  367883.2170436438
# 41.8191171458797
# ------------------------------------------------------
# C2015-17.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  281070.0
# Gia tri du doan:  325373.6228708774
# 84.2375127651911
# 25%:
# Gia tri thuc:  281070.0
# Gia tri du doan:  154542.70131089538
# 54.983705593231356
# C2015-17.csv 25 281070.0 154542.70131089538 54.983705593231356
# 1 -> 25%:
# Gia tri thuc:  281070.0
# Gia tri du doan:  137157.94142746553
# 48.798499102524474
# 50%:
# Gia tri thuc:  281070.0
# Gia tri du doan:  264609.1813253239
# 94.14351632167214
# 1 -> 50%:
# Gia tri thuc:  281070.0
# Gia tri du doan:  145850.32136918046
# 51.89110234787792
# ------------------------------------------------------
# C2016-06.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  4331260.485881811
# Gia tri du doan:  8036746.7483060295
# 14.447854741070598
# 25%:
# Gia tri thuc:  4331260.485881811
# Gia tri du doan:  1058928.2902471647
# 24.4485016243851
# C2016-06.csv 25 4331260.485881811 1058928.2902471647 24.4485016243851
# 1 -> 25%:
# Gia tri thuc:  4331260.485881811
# Gia tri du doan:  416068.8864336622
# 9.606184799780149
# 50%:
# Gia tri thuc:  4331260.485881811
# Gia tri du doan:  2527475.376356341
# 58.35426856904375
# 1 -> 50%:
# Gia tri thuc:  4331260.485881811
# Gia tri du doan:  1445674.6159927493
# 33.377688105000246
# ------------------------------------------------------
# C2013-15.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  308343.775537491
# Gia tri du doan:  437951.2098544178
# 57.96657996711596
# 25%:
# Gia tri thuc:  308343.775537491
# Gia tri du doan:  228618.17934987321
# 74.14392554263704
# C2013-15.csv 25 308343.775537491 228618.17934987321 74.14392554263704
# 1 -> 25%:
# Gia tri thuc:  308343.775537491
# Gia tri du doan:  158295.1119738929
# 51.33721661738102
# 50%:
# Gia tri thuc:  308343.775537491
# Gia tri du doan:  617041.6884153374
# 0
# 1 -> 50%:
# Gia tri thuc:  308343.775537491
# Gia tri du doan:  253419.01426767805
# 82.18716717272123
# ------------------------------------------------------
# C2015-03.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  1868796.28351921
# Gia tri du doan:  1422066.0945458068
# 76.09529765694168
# 25%:
# Gia tri thuc:  1868796.28351921
# Gia tri du doan:  737640.6151275858
# 39.47142990559159
# C2015-03.csv 25 1868796.28351921 737640.6151275858 39.47142990559159
# 1 -> 25%:
# Gia tri thuc:  1868796.28351921
# Gia tri du doan:  205706.8943816293
# 11.00745416692791
# 50%:
# Gia tri thuc:  1868796.28351921
# Gia tri du doan:  1041208.0991102047
# 55.71544144712559
# 1 -> 50%:
# Gia tri thuc:  1868796.28351921
# Gia tri du doan:  523894.2142366115
# 28.03377868721164
# ------------------------------------------------------
# data_18.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  1425155.961
# Gia tri du doan:  1536203.3052338166
# 92.20805671290199
# 25%:
# Gia tri thuc:  1425155.961
# Gia tri du doan:  1001511.1941275112
# 70.2737960991142
# data_18.csv 25 1425155.961 1001511.1941275112 70.2737960991142
# 1 -> 25%:
# Gia tri thuc:  1425155.961
# Gia tri du doan:  418316.62009389885
# 29.35233978184223
# 50%:
# Gia tri thuc:  1425155.961
# Gia tri du doan:  1681054.8045197874
# 82.04415162111599
# 1 -> 50%:
# Gia tri thuc:  1425155.961
# Gia tri du doan:  839141.8159672096
# 58.88070070439186
# ------------------------------------------------------
# C2015-23.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  32805.0
# Gia tri du doan:  149433.25968876295
# 0
# 25%:
# Gia tri thuc:  32805.0
# Gia tri du doan:  142539.03629235923
# 0
# C2015-23.csv 25 32805.0 142539.03629235923 0
# 1 -> 25%:
# Gia tri thuc:  32805.0
# Gia tri du doan:  136628.7118181102
# 0
# 50%:
# Gia tri thuc:  32805.0
# Gia tri du doan:  156521.1070201099
# 0
# 1 -> 50%:
# Gia tri thuc:  32805.0
# Gia tri du doan:  139583.87405523472
# 0
# ------------------------------------------------------
# C2019-6.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  1534060.0
# Gia tri du doan:  1208739.016044858
# 78.79346414383126
# 25%:
# Gia tri thuc:  1534060.0
# Gia tri du doan:  284007.64607292786
# 18.51346401528805
# C2019-6.csv 25 1534060.0 284007.64607292786 18.51346401528805
# 1 -> 25%:
# Gia tri thuc:  1534060.0
# Gia tri du doan:  143705.85117143765
# 9.367681262234706
# 50%:
# Gia tri thuc:  1534060.0
# Gia tri du doan:  1038239.7069806978
# 67.67921117692252
# 1 -> 50%:
# Gia tri thuc:  1534060.0
# Gia tri du doan:  392668.94824800343
# 25.596713834400443
# ------------------------------------------------------
# C2015-16.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  64125.0
# Gia tri du doan:  161560.36778942743
# 0
# 25%:
# Gia tri thuc:  64125.0
# Gia tri du doan:  137294.15122762322
# 0
# C2015-16.csv 25 64125.0 137294.15122762322 0
# 1 -> 25%:
# Gia tri thuc:  64125.0
# Gia tri du doan:  136504.9946548827
# 0
# 50%:
# Gia tri thuc:  64125.0
# Gia tri du doan:  159749.79710162804
# 0
# 1 -> 50%:
# Gia tri thuc:  64125.0
# Gia tri du doan:  138926.5112895742
# 0
# ------------------------------------------------------
# C2016-25.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  56748.3294067383
# Gia tri du doan:  162099.5108649563
# 0
# 25%:
# Gia tri thuc:  56748.3294067383
# Gia tri du doan:  151375.3018721752
# 0
# C2016-25.csv 25 56748.3294067383 151375.3018721752 0
# 1 -> 25%:
# Gia tri thuc:  56748.3294067383
# Gia tri du doan:  141758.4934492521
# 0
# 50%:
# Gia tri thuc:  56748.3294067383
# Gia tri du doan:  165740.46605211496
# 0
# 1 -> 50%:
# Gia tri thuc:  56748.3294067383
# Gia tri du doan:  146566.89766071364
# 0
# ------------------------------------------------------
# C2016-32.csv
# Độ chính xác dự đoán thời gian của dữ liệu K62:
# Tất cả thời điểm:
# Gia tri thuc:  496991.0
# Gia tri du doan:  527367.0981957847
# 93.88799833482202
# 25%:
# Gia tri thuc:  496991.0
# Gia tri du doan:  460066.9372936487
# 92.57047658682929
# C2016-32.csv 25 496991.0 460066.9372936487 92.57047658682929
# 1 -> 25%:
# Gia tri thuc:  496991.0
# Gia tri du doan:  236793.64330604672
# 47.645459033674
# 50%:
# Gia tri thuc:  496991.0
# Gia tri du doan:  539390.4032358155
# 91.46877846161892
# 1 -> 50%:
# Gia tri thuc:  496991.0
# Gia tri du doan:  348430.2902998477
# 70.10796781025164
# ------------------------------------------------------

# %%
import matplotlib.pyplot as plt
filetest = open(fileTest,'r')

for line in filetest: 
  li2=[]
  df = pd.read_csv(line.strip(), index_col = None, header = 0)
  li2.append(df)  
  dataFrame2 = pd.concat(li2, axis = 0, ignore_index = True)
  X_test, y_test = dataFrame2.iloc[:, [2, 3]], dataFrame2.iloc[:, 7] 
  preds = loaded_model.predict(X_test)

  dir = line.replace(path,"")
  print("Giá trị thực: ")
  print(y_test)
  print("Giá trị dự đoán: ")
  print(preds)
  plt.plot(preds, 'o', color = 'r')
  plt.plot(y_test, 'x', color = 'b')
  plt.title(dir)
  plt.xlabel("STT")
  plt.ylabel("Time")
  
  plt.legend(('prediction', 'reality'), loc = 'upper right')
  
  plt.show()
# Out:
# Giá trị thực:
# 0    57822.39978
# 1    57822.39978
# 2    57822.39978
# 3    57822.39978
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [141232.57686212 151242.64394061 168111.81469252 190891.77640414]
# Giá trị thực:
# 0    5414544
# 1    5414544
# 2    5414544
# 3    5414544
# 4    5414544
# 5    5414544
# 6    5414544
# 7    5414544
# 8    5414544
# Name: TOTAL_AC, dtype: int64
# Giá trị dự đoán:
# [  899767.58329314  1373219.1077546   2681401.85660792  9991504.00032857
#  10890787.2961536  10890787.2961536  24812729.32936773 25980688.77771788
#  25953912.39874506]
# Giá trị thực:
# 0     3.977764e+07
# 1     3.977764e+07
# 2     3.977764e+07
# 3     3.977764e+07
# 4     3.977764e+07
# 5     3.977764e+07
# 6     3.977764e+07
# 7     3.977764e+07
# 8     3.977764e+07
# 9     3.977764e+07
# 10    3.977764e+07
# 11    3.977764e+07
# 12    3.977764e+07
# 13    3.977764e+07
# 14    3.977764e+07
# 15    3.977764e+07
# 16    3.977764e+07
# 17    3.977764e+07
# 18    3.977764e+07
# 19    3.977764e+07
# 20    3.977764e+07
# 21    3.977764e+07
# 22    3.977764e+07
# 23    3.977764e+07
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [ 2690428.47517104  2690428.47517104 25085036.92503346 25085036.92503346
#  25438301.51676022 25921174.79056899 26087596.23253989 26087596.23253989
#  27242706.508796   24723723.75599923 26090801.42104333 33425299.31392562
#  36009869.3060763  33425245.85732073 33435220.22731815 33689545.14809301
#  34557804.42745604 34557804.42745604 41795425.27707168 41795425.27707168
#  41795425.27707168 42874133.17938608 42878626.63196246 42878626.63196246]
# Giá trị thực:
# 0    586086.849976
# 1    586086.849976
# 2    586086.849976
# 3    586086.849976
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [379590.64472879 860989.88443883 873384.10277694 933217.46914185]
# Giá trị thực:
# 0     906253.867188
# 1     906253.867188
# 2     906253.867188
# 3     906253.867188
# 4     906253.867188
# 5     906253.867188
# 6     906253.867188
# 7     906253.867188
# 8     906253.867188
# 9     906253.867188
# 10    906253.867188
# 11    906253.867188
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [ 143626.05524937  174400.09881292  701503.47719862  825998.54181753
#   845498.69544122  902469.9975762   927683.24665889  940665.20302991
#  1018834.2793732  1084087.18161021 1114977.5353618  1145091.81262064]
# Giá trị thực:
# 0     191065.059996
# 1     191065.059996
# 2     191065.059996
# 3     191065.059996
# 4     191065.059996
# 5     191065.059996
# 6     191065.059996
# 7     191065.059996
# 8     191065.059996
# 9     191065.059996
# 10    191065.059996
# 11    191065.059996
# 12    191065.059996
# 13    191065.059996
# 14    191065.059996
# 15    191065.059996
# 16    191065.059996
# 17    191065.059996
# 18    191065.059996
# 19    191065.059996
# 20    191065.059996
# 21    191065.059996
# 22    191065.059996
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
#
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [ 148977.50218691  586788.93190037  966778.9748105  1114942.53558438]
# Giá trị thực:
# 0    281070
# 1    281070
# 2    281070
# 3    281070
# 4    281070
# Name: TOTAL_AC, dtype: int64
# Giá trị dự đoán:
# [137157.94142747 154542.7013109  264609.18132532 484847.29505878
#  585710.99523193]
# Giá trị thực:
# 0     4.331260e+06
# 1     4.331260e+06
# 2     4.331260e+06
# 3     4.331260e+06
# 4     4.331260e+06
# 5     4.331260e+06
# 6     4.331260e+06
# 7     4.331260e+06
# 8     4.331260e+06
# 9     4.331260e+06
# 10    4.331260e+06
# 11    4.331260e+06
# 12    4.331260e+06
# 13    4.331260e+06
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [  135188.02732838   158612.34260873   954406.28936388  1058928.29024716
#   2435644.05433426  2668001.40248157  2708941.90558527  2527475.37635634
#   3330126.13223951 15167185.09569174 19235401.29903635 20001435.79369558
#  21039159.96443573 21093948.50287993]
# Giá trị thực:
# 0    308343.775537
# 1    308343.775537
# 2    308343.775537
# 3    308343.775537
# 4    308343.775537
# 5    308343.775537
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [158295.11197389 228618.17934987 373343.75147927 617041.68841534
#  617041.68841534 633366.8394928 ]
# Giá trị thực:
# 0    1.868796e+06
# 1    1.868796e+06
# 2    1.868796e+06
# 3    1.868796e+06
# 4    1.868796e+06
# 5    1.868796e+06
# 6    1.868796e+06
# 7    1.868796e+06
# 8    1.868796e+06
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [ 193915.67303282  217498.11573044  737640.61512759  946522.4530556
#  1041208.0991102  1777919.99908942 2487474.37765129 2706007.31562761
#  2690408.20248729]
# Giá trị thực:
# 0    1425155.961
# 1    1425155.961
# 2    1425155.961
# 3    1425155.961
# 4    1425155.961
# 5    1425155.961
# 6    1425155.961
# 7    1425155.961
# 8    1425155.961
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [ 172441.73707107  664191.50311673 1001511.19412751 1518422.82955353
#  1681054.80451979 1954645.34124166 2241866.75733496 2295847.79006955
#  2295847.79006955]
# Giá trị thực:
# 0    32805
# 1    32805
# 2    32805
# 3    32805
# Name: TOTAL_AC, dtype: int64
# Giá trị dự đoán:
# [136628.71181811 142539.03629236 156521.10702011 162044.18362447]
# Giá trị thực:
# 0     1534060
# 1     1534060
# 2     1534060
# 3     1534060
# 4     1534060
# 5     1534060
# 6     1534060
# 7     1534060
# 8     1534060
# 9     1534060
# 10    1534060
# Name: TOTAL_AC, dtype: int64
# Giá trị dự đoán:
# [ 139832.62560024  147579.07674263  284007.64607293  503244.12878441
#   888681.2640398  1038239.7069807  1549860.87843627 1886329.15047042
#  2121535.46784815 2224255.84129147 2512563.39022642]
# Giá trị thực:
# 0    64125
# 1    64125
# 2    64125
# 3    64125
# 4    64125
# 5    64125
# Name: TOTAL_AC, dtype: int64
# Giá trị dự đoán:
# [136504.99465488 137294.15122762 142980.38798622 159749.79710163
#  193698.45166574 199134.42410047]
# Giá trị thực:
# 0    56748.329407
# 1    56748.329407
# 2    56748.329407
# 3    56748.329407
# Name: TOTAL_AC, dtype: float64
# Giá trị dự đoán:
# [141758.49344925 151375.30187218 165740.46605211 189523.78208628]
# Giá trị thực:
# 0    496991
# 1    496991
# 2    496991
# 3    496991
# Name: TOTAL_AC, dtype: int64
# Giá trị dự đoán:
# [236793.64330605 460066.93729365 539390.40323582 873217.40894763]
